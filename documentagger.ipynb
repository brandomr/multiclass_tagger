# %%
import numpy as np
import pandas as pd
import nltk
import re
import os
import codecs

# %%
metadata = pd.read_csv("DocumentTagResults.csv")

# %%
metadata.columns
# Out:
# Index([u'DocumentID', u'Subject', u'FileName', u'TagName'], dtype='object')

# %%
metadata['FileName'] = metadata['FileName'].replace(to_replace='.docx', value='.htm', regex=True)

# %%
filenames = os.listdir('docs')
#gets list of filenames in the document directory

len(filenames)
#tests how many files are in the docs folder
# Out:
# 60

# %%
corpora = []

for i in filenames:
    doc = open('docs/'+ i)
    text = doc.read()
    #grabs the document as variable text
    
    text = nltk.clean_html(text)
    #strips html formatting
    
    text = text.replace('&#xa0;', '\xA0')
    text = text.decode('utf-8', 'ignore')
    #gets rid of non-break space html and converts to unicode
    
    corpora.append(text)
    #adds to corpora

# %%
def extract_entities(text):
    entities = []
    for sentence in nltk.sent_tokenize(text):
        chunks = nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sentence)))
        entities.extend([chunk for chunk in chunks if hasattr(chunk, 'node')])
    return entities

# %%
def uniq(input):
    output = []
    for x in input: 
        if x not in output:
            output.append(x)
    return output

for entity in extract_entities(corpora[0]):
    entitylist = '[' + entity.node + '] ' + ' '.join(c[0] for c in entity.leaves())
    print entitylist
# Out:
# [GPE] Sudan
# [ORGANIZATION] UNCLASSIFIED
# [PERSON] Princeton Lyman
# [GPE] Sudan
# [GPE] South Sudan
# [ORGANIZATION] SBU
# [GPE] Sudan
# [GPE] South Sudan
# [GPE] United States
# [GPE] Sudan
# [GPE] South Sudan
# [GPE] U.S.
# [PERSON] Sudan
# [GPE] South Sudan
# [GPE] Sudan
# [GPE] South Sudan
# [GPE] Abyei
# [ORGANIZATION] African Union
# [GPE] Sudan
# [GPE] South Sudan
# [GPE] South Sudan
# [GPE] Sudan
# [GPE] United States
# [PERSON] Stability Within
# [ORGANIZATION] States
# [ORGANIZATION] SBU
# [PERSON] Africa
# [PERSON] Sudan
# [GPE] Darfur
# [LOCATION] Southern Kordofan
# [PERSON] Blue Nile
# [PERSON] Arab
# [GPE] Sudan
# [GPE] Ethiopia
# [GSP] Uganda
# [GPE] Eritrea
# [PERSON] Chad
# [GPE] Instability
# [GPE] East African
# [GPE] Somalia
# [GPE] Sudan
# [GPE] United States
# [GPE] United States
# [GPE] Darfur
# [GPE] Sudan
# [GPE] United States
# [GPE] Sudan
# [ORGANIZATION] Comprehensiv
# [PERSON] Peace Agreement
# [ORGANIZATION] CPA
# [PERSON] Kenya
# [ORGANIZATION] General
# [ORGANIZATION] UK
# [GPE] Norway
# [ORGANIZATION] CPA
# [GPE] South Sudan
# [ORGANIZATION] SBU
# [ORGANIZATION] CPA
# [GPE] Sudan
# [GSP] Conflict
# [GPE] Sudan
# [GPE] South Sudan
# [ORGANIZATION] CPA
# [ORGANIZATION] AU
# [ORGANIZATION] AU
# [GPE] Sudan
# [GPE] South Sudan
# [GPE] South Sudan
# [GPE] Abyei
# [ORGANIZATION] AU
# [GPE] South Sudan
# [GPE] Sudan
# [ORGANIZATION] AU
# [PERSON] Khartoum
# [GPE] South Sudan
# [GPE] Sudanese
# [ORGANIZATION] SBU
# [GPE] Sudan
# [GPE] South Sudan
# [ORGANIZATION] AU
# [ORGANIZATION] AU
# [PERSON] Council
# [ORGANIZATION] UNSC
# [ORGANIZATION] AU
# [ORGANIZATION] UNSC
# [GPE] Sudan
# [ORGANIZATION] Abyei
# [ORGANIZATION] AU
# [ORGANIZATION] UNSC
# [ORGANIZATION] AU
# [PERSON] Thabo Mbeki
